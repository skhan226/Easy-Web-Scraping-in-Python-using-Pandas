# %% [markdown]
# <a href="https://colab.research.google.com/github/skhan226/Easy-Web-Scraping-in-Python-using-Pandas/blob/main/pandas_read_html_for_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Using pandas read_html to Web Scrape Data for Data Science**
#
# Shoeb Ahmed Khan
#
# In this Jupyter notebook, I will be showing you how to easily web scrape data using pandas read_html() function for your data science project. We will be web scraping NBA player stats data and perform a quick data exploration.

# %% [markdown]
# ## **URL to the webpage "NFL 2021 Draft"**

# %% [markdown]
# ### Method 1
#
# We could modularize the URL and year strings of text that may be useful for programmatic access (in the subsequent code cell).

# %%
# The Building Blocks

year = '2021'
str = 'https://www.pro-football-reference.com/years/{}/draft.htm#site_menu_link'

#Combining the URL + year strings together
url = str.format(year)
url
# Out:
# 'https://www.pro-football-reference.com/years/2021/draft.htm#site_menu_link'

# %% [markdown]
# Now, let's programmatically return a list of URL given a list of years (e.g. 2015,2016,2017,2018,2019).

# %%
years = [2015,2016,2017,2018,2019]
url_link = 'https://www.pro-football-reference.com/years/{}/draft.htm#site_menu_link'

for year in years:
  url = url_link.format(year)
  print(url)
# Out:
# https://www.pro-football-reference.com/years/2015/draft.htm#site_menu_link
# https://www.pro-football-reference.com/years/2016/draft.htm#site_menu_link
# https://www.pro-football-reference.com/years/2017/draft.htm#site_menu_link
# https://www.pro-football-reference.com/years/2018/draft.htm#site_menu_link
# https://www.pro-football-reference.com/years/2019/draft.htm#site_menu_link

# %% [markdown]
# Method 2

# %%
url = 'https://www.pro-football-reference.com/years/2021/draft.htm#site_menu_link'

# %% [markdown]
# ## **Read HTML webpage into pandas**

# %%
import pandas as pd

# %% [markdown]
# ### Using pd.read_html() function to read HTML webpage

# %%
df = pd.read_html(url,header = 1)
df
# Out:
# [    Rnd Pick   Tm            Player  ... Int.1   Sk      College/Univ    Unnamed: 28
#  0     1    1  JAX   Trevor Lawrence  ...   NaN  NaN           Clemson  College Stats
#  1     1    2  NYJ       Zach Wilson  ...   NaN  NaN               BYU  College Stats
#  2     1    3  SFO        Trey Lance  ...   NaN  NaN  North Dakota St.  College Stats
#  3     1    4  ATL        Kyle Pitts  ...   NaN  NaN           Florida  College Stats
#  4     1    5  CIN     Ja'Marr Chase  ...   NaN  NaN               LSU  College Stats
#  ..   ..  ...  ...               ...  ...   ...  ...               ...            ...
#  260   7  255  NOR      Kawaan Baker  ...   NaN  NaN     South Alabama  College Stats
#  261   7  256  GNB        Kylin Hill  ...   NaN  NaN   Mississippi St.  College Stats
#  262   7  257  DET  Jermar Jefferson  ...   NaN  NaN        Oregon St.  College Stats
#  263   7  258  WAS         Dax Milne  ...   NaN  NaN               BYU  College Stats
#  264   7  259  TAM      Grant Stuard  ...   NaN  NaN           Houston  College Stats
#
#  [265 rows x 29 columns]]

# %% [markdown]
# ### How many tables are there in the webpage?

# %%
len(df)
# Out:
# 1

# %% [markdown]
# ### Select the first table

# %%
df[0]
# Out:
#     Rnd Pick   Tm            Player  ... Int.1   Sk      College/Univ    Unnamed: 28
# 0     1    1  JAX   Trevor Lawrence  ...   NaN  NaN           Clemson  College Stats
# 1     1    2  NYJ       Zach Wilson  ...   NaN  NaN               BYU  College Stats
# 2     1    3  SFO        Trey Lance  ...   NaN  NaN  North Dakota St.  College Stats
# 3     1    4  ATL        Kyle Pitts  ...   NaN  NaN           Florida  College Stats
# 4     1    5  CIN     Ja'Marr Chase  ...   NaN  NaN               LSU  College Stats
# ..   ..  ...  ...               ...  ...   ...  ...               ...            ...
# 260   7  255  NOR      Kawaan Baker  ...   NaN  NaN     South Alabama  College Stats
# 261   7  256  GNB        Kylin Hill  ...   NaN  NaN   Mississippi St.  College Stats
# 262   7  257  DET  Jermar Jefferson  ...   NaN  NaN        Oregon St.  College Stats
# 263   7  258  WAS         Dax Milne  ...   NaN  NaN               BYU  College Stats
# 264   7  259  TAM      Grant Stuard  ...   NaN  NaN           Houston  College Stats
#
# [265 rows x 29 columns]

# %%
df2021 = df[0]

# %%
df2021
# Out:
#     Rnd Pick   Tm            Player  ... Int.1   Sk      College/Univ    Unnamed: 28
# 0     1    1  JAX   Trevor Lawrence  ...   NaN  NaN           Clemson  College Stats
# 1     1    2  NYJ       Zach Wilson  ...   NaN  NaN               BYU  College Stats
# 2     1    3  SFO        Trey Lance  ...   NaN  NaN  North Dakota St.  College Stats
# 3     1    4  ATL        Kyle Pitts  ...   NaN  NaN           Florida  College Stats
# 4     1    5  CIN     Ja'Marr Chase  ...   NaN  NaN               LSU  College Stats
# ..   ..  ...  ...               ...  ...   ...  ...               ...            ...
# 260   7  255  NOR      Kawaan Baker  ...   NaN  NaN     South Alabama  College Stats
# 261   7  256  GNB        Kylin Hill  ...   NaN  NaN   Mississippi St.  College Stats
# 262   7  257  DET  Jermar Jefferson  ...   NaN  NaN        Oregon St.  College Stats
# 263   7  258  WAS         Dax Milne  ...   NaN  NaN               BYU  College Stats
# 264   7  259  TAM      Grant Stuard  ...   NaN  NaN           Houston  College Stats
#
# [265 rows x 29 columns]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# We can see that the table header is presented multiple times in several rows.

# %%
df2021[df2021.Age == 'Age']
# Out:
#      Rnd  Pick  Tm  Player  Pos  ...  Solo Int.1  Sk  College/Univ Unnamed: 28
# 32   Rnd  Pick  Tm  Player  Pos  ...  Solo   Int  Sk  College/Univ         NaN
# 65   Rnd  Pick  Tm  Player  Pos  ...  Solo   Int  Sk  College/Univ         NaN
# 107  Rnd  Pick  Tm  Player  Pos  ...  Solo   Int  Sk  College/Univ         NaN
# 147  Rnd  Pick  Tm  Player  Pos  ...  Solo   Int  Sk  College/Univ         NaN
# 188  Rnd  Pick  Tm  Player  Pos  ...  Solo   Int  Sk  College/Univ         NaN
# 233  Rnd  Pick  Tm  Player  Pos  ...  Solo   Int  Sk  College/Univ         NaN
#
# [6 rows x 29 columns]

# %%
len(df2021[df2021.Age == 'Age'])
# Out:
# 6

# %%
df = df2021.drop(df2021[df2021.Age == 'Age'].index)

# %%
df.shape
# Out:
# (259, 29)

# %% [markdown]
# ## Quick Exploratory Data Analysis

# %%
import seaborn as sns

# %% [markdown]
# Making the histogram

# %%
sns.distplot(df.G,kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Change bar line color

# %%
sns.distplot(df.G, 
             kde=False,
             hist_kws=dict(edgecolor="black", linewidth=2))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Change bar fill colors

# %%
sns.distplot(df.G,
             kde=False,
             hist_kws=dict(edgecolor="black", linewidth=2),
             color='#00BFC4')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
